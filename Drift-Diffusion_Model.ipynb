# %%
import numpy as np
from DDGelectron_driftdiffusion import *
from DDGnlpoisson import *
from func_lib import *
# from DDGgummelmap import *
# Define sample inputs
psi = np.linspace(0, 1, 10)  # Electric potential
xaxis = np.linspace(0, 1, 10)  # Integration domain
ng = np.ones(10)  # Initial guess and BCs for electron density
p = np.ones(10) * 1e15  # Hole density
ni = 1.45e10  # Intrinsic carrier concentration
TAUN0 = 1e-7  # Electron lifetime
TAUP0 = 1e-7  # Hole lifetime
mun = 1350  # Electron mobility
fi_e = np.zeros(10)  # Electric quasi-Fermi level for electrons
fi_h = np.zeros(10)  # Electric quasi-Fermi level for holes
model = type('Model', (object,), {"N_wells_virtual": 2})  # Model instance
Vt = 0.026  # Thermal voltage
idata = type('Idata', (object,), {"wfh_general": 0, "wfe_general": 0, "E_state_general": 0, 
                                  "E_statec_general": 0, "meff_state_general": 0, "meff_statec_general": 0, 
                                  "n": 0})  # Input data instance

# Call the function
n = DDGelectron_driftdiffusion(psi, xaxis, ng, p, ni, TAUN0, TAUP0, mun, fi_e, fi_h, model, Vt, idata)

# Output the result
print("Updated electron density:", n)
# Out:
# Updated electron density: [1.00000000e+00 1.61017958e+00 2.10248201e+05 2.10250000e+05
#  2.10250000e+05 2.10250000e+05 2.10250000e+05 2.10248390e+05
#  1.79940610e+00 1.00000000e+00]

# %%
import numpy as np
from DDGhole_driftdiffusion import *

error=1e-5
# Define sample inputs
psi = np.linspace(0, 1, 10)  # Electric potential
xaxis = np.linspace(0, 1, 10)  # Spatial grid
pg = np.ones(10)  # Initial guess and BCs for hole density
n = np.ones(10) * 1e15  # Electron density
ni = 1.45e10  # Intrinsic carrier concentration
TAUN0 = 1e-7  # Electron lifetime
TAUP0 = 1e-7  # Hole lifetime
mup = 450  # Hole mobility
fi_e = np.zeros(10)  # Electric quasi-Fermi level for electrons
fi_h = np.zeros(10)  # Electric quasi-Fermi level for holes
model = type('Model', (object,), {"N_wells_virtual": 2})  # Model instance
Vt = 0.026  # Thermal voltage
idata = type('Idata', (object,), {"wfh_general": 0, "wfe_general": 0, "E_state_general": 0, 
                                  "E_statec_general": 0, "meff_state_general": 0, "meff_statec_general": 0, 
                                  "p": 0})  # Input data instance

# Call the function
p = DDGhole_driftdiffusion(psi, xaxis, pg, n, ni, TAUN0, TAUP0, mup, fi_e, fi_h, model, Vt, idata)

# Output the result
print("Updated hole density:", p)
# Out:
# Updated hole density: [1.00000000e+00 1.79940610e+00 2.10248390e+05 2.10250000e+05
#  2.10250000e+05 2.10250000e+05 2.10250000e+05 2.10248201e+05
#  1.61017958e+00 1.00000000e+00]

# %%
def DDGgummelmap(n_max, xaxis, idata, odata, toll, maxit, ptoll, pmaxit, verbose, ni, fi_e, fi_h, model, Vt, error):
    odata  = idata
    dop = idata.dop
    Ppz_Psp = idata.Ppz_Psp
    vout = np.zeros((n_max, 2))
    hole_density = np.zeros((n_max, 3))
    electron_density = np.zeros((n_max, 3))
    fermin = np.zeros((n_max, 2))
    fermip = np.zeros((n_max, 2))
    v_Nnodes = np.arange(n_max)

    vout[:,0] = idata.V
    hole_density[:,0] = idata.p
    electron_density[:,0] = idata.n
    fermin[:,0] = idata.Fn
    fermip[:,0] = idata.Fp
    nrm = np.zeros(maxit)

    print("=======================================")
    for i in range(maxit):
        if verbose > 1:
            print("*****************************************************************")
            print("****    start of gummel iteration number:", i)
            print("*****************************************************************")
            print("solving non linear poisson equation")

        # Solve the non-linear Poisson equation
        [vout[:,1], electron_density[:,1], hole_density[:,1]] = DDGnlpoisson(
            idata, xaxis, v_Nnodes, vout[:,0], electron_density[:,0], hole_density[:,0], 
            fermin[:,0], fermip[:,0], dop, Ppz_Psp, idata.l2, ptoll, pmaxit, verbose, ni, fi_e, fi_h, model, Vt
        )

        if verbose > 1:
            print("updating electron qfl")

        # Update electron quasi-Fermi level
        electron_density[:,2] = DDGelectron_driftdiffusion(
            vout[:,1], xaxis, electron_density[:,1], hole_density[:,1], idata.nis, 
            idata.TAUN0, idata.TAUP0, idata.mun, fi_e, fi_h, model, Vt, idata
        )

        fermin[:,1] = DDGn2phin(vout[:,1], electron_density[:,2])
        fermin[0,1] = idata.Fn[0]
        fermin[n_max-1,1] = idata.Fn[-1]

        if verbose > 1:
            print("updating hole qfl")

        # Update hole quasi-Fermi level
        hole_density[:,2] = DDGhole_driftdiffusion(
            vout[:,1], xaxis, hole_density[:,1], electron_density[:,1], idata.nis, 
            idata.TAUN0, idata.TAUP0, idata.mup, fi_e, fi_h, model, Vt, idata
        )

        fermip[:,1] = DDGp2phip(vout[:,1], hole_density[:,2])
        fermip[0,1] = idata.Fp[0]
        fermip[n_max-1,1] = idata.Fp[-1]

        if verbose > 1:
            print("checking for convergence")

        nrfn = np.linalg.norm(fermin[:,1] - fermin[:,0], np.inf)
        nrfp = np.linalg.norm(fermip[:,1] - fermip[:,0], np.inf)
        nrv = np.linalg.norm(vout[:,1] - vout[:,0], np.inf)
        nrm[i] = max(nrfn, nrfp, nrv)

        if verbose > 1:
            print("max(|phin_(k+1)-phin_(k)| , |phip_(k+1)-phip_(k)| , |v_(k+1)- v_(k)|) =", nrm[i])

        if nrm[i] < error:
            break

        vout[:,0] = vout[:,1]
        hole_density[:,0] = hole_density[:,2]
        electron_density[:,0] = electron_density[:,2]
        fermin[:,0] = fermin[:,1]
        fermip[:,0] = fermip[:,1]

    it = i
    res = nrm

    if verbose > 0:
        print("\n\nInitial guess computed by DD: # of Gummel iterations =", it)

    odata.n = electron_density[:,2]
    odata.p = hole_density[:,2]
    odata.V = vout[:,1]
    odata.Fn = fermin[:,1]
    odata.Fp = fermip[:,1]

    return [odata, it, res]

# %%
# Assuming all necessary functions and configurations are correctly imported and defined
# Define the necessary imports and functions for your model

# Define sample inputs for DDGgummelmap
n_max = 1000
xaxis = np.linspace(0, 1, n_max)  # Spatial grid
ni = 1.45e10  # Intrinsic carrier concentration
fi_e = np.zeros(n_max)  # Electric quasi-Fermi level for electrons
fi_h = np.zeros(n_max)  # Electric quasi-Fermi level for holes
Vt = 0.026  # Thermal voltage

# Define your model and idata objects
model = type('Model', (object,), {"N_wells_virtual": 2, "quantum_effect": True})
idata = type('Idata', (object,), {
    "dop": np.ones(n_max),
    "Ppz_Psp": np.zeros(n_max),
    "l2": 1.0,
    "nis": ni,
    "TAUN0": 1e-7,
    "TAUP0": 1e-7,
    "mun": 1400,
    "mup": 450,
    "wfh_general": 0,
    "wfe_general": 0,
    "E_state_general": 0,
    "E_statec_general": 0,
    "meff_state_general": 0,
    "meff_statec_general": 0,
    "p": np.ones(n_max) * 1e15,
    "n": np.ones(n_max) * 1e15,
    "Fn": np.zeros(n_max),
    "Fp": np.zeros(n_max),
    "V": np.zeros(n_max)
})

odata = idata  # Assuming initial guess is same as idata for simplicity
toll = 1e-5
maxit = 1000
ptoll = 1e-5
error=1e-5
pmaxit = 1000
error=1e-5
verbose = 2

# %%
# Call the DDGgummelmap function
result_odata, iterations, residuals = DDGgummelmap(n_max=n_max, 
                                                   xaxis=xaxis, 
                                                   idata=idata, 
                                                   odata=odata, 
                                                   toll=toll, 
                                                   maxit=maxit, 
                                                   ptoll=ptoll, 
                                                   pmaxit=pmaxit, 
                                                   verbose=verbose, 
                                                   ni=ni, 
                                                   fi_e=fi_e, 
                                                   fi_h=fi_h, 
                                                   model=model, 
                                                   Vt=Vt, 
                                                   error=error)

# Output the results
print("Resulting odata:", result_odata)
print("Number of iterations:", iterations)
print("Residuals:", residuals)
# Out:
# =======================================
# *****************************************************************
# ****    start of gummel iteration number: 0
# *****************************************************************
# solving non linear poisson equation
#
#  newton iteration: 1, reldVnorm = 1.000000
#
#  damping iteration: 1, residual norm = 0.001001
#
#  damping iteration: 2, residual norm = 0.430714
#
#  damping iteration: 3, residual norm = 0.086944
#
#  damping iteration: 4, residual norm = 0.018190
#
#  damping iteration: 5, residual norm = 0.004439
#
#  damping iteration: 6, residual norm = 0.001689
#
#  damping iteration: 7, residual norm = 0.001139
#
#  damping iteration: 8, residual norm = 0.001029
#
#  damping iteration: 9, residual norm = 0.001007
#
#  newton iteration: 2, reldVnorm = 0.200000
#
#  damping iteration: 1, residual norm = 0.001002
#
# exiting damping cycle because residual norm = 0.000000
#
#
#  newton iteration: 3, reldVnorm = 0.999997
#
#  damping iteration: 1, residual norm = 0.000000
#
# exiting damping cycle because residual norm = 0.000000
#
#
#  newton iteration: 4, reldVnorm = 0.000249
#
#  damping iteration: 1, residual norm = 0.000000
#
# exiting damping cycle because residual norm = 0.000000
#
#
# exiting newton cycle because reldVnorm= 0.000000
#
# updating electron qfl
# updating hole qfl
# checking for convergence
# max(|phin_(k+1)-phin_(k)| , |phip_(k+1)-phip_(k)| , |v_(k+1)- v_(k)|) = 36.98201734006485
# *****************************************************************
# ****    start of gummel iteration number: 1
# *****************************************************************
# solving non linear poisson equation
#
#  newton iteration: 1, reldVnorm = 1.000000
#
#  damping iteration: 1, residual norm = 268946628653.161804
#
#  damping iteration: 2, residual norm = 2183221449.331820
#
# exiting damping cycle
#
#
#  newton iteration: 2, reldVnorm = 0.026245
#
#  damping iteration: 1, residual norm = 2183221449.331820
#
#  damping iteration: 2, residual norm = 215143487436.995789
#
# exiting damping cycle
#
#
#  newton iteration: 3, reldVnorm = 0.002086
#
#  damping iteration: 1, residual norm = 215143487436.995789
#
# exiting damping cycle because residual norm = 1746576400.764232
#
#
#  newton iteration: 4, reldVnorm = 0.116825
#
#  damping iteration: 1, residual norm = 1746576400.764232
#
# exiting damping cycle because residual norm = 411.497273
#
#
#  newton iteration: 5, reldVnorm = 0.009284
#
#  damping iteration: 1, residual norm = 411.497273
#
# exiting damping cycle because residual norm = 0.147632
#
#
# exiting newton cycle because reldVnorm= 0.000000
#
# updating electron qfl
# updating hole qfl
# checking for convergence
# max(|phin_(k+1)-phin_(k)| , |phip_(k+1)-phip_(k)| , |v_(k+1)- v_(k)|) = 26.988088423820805
# *****************************************************************
# ****    start of gummel iteration number: 2
# *****************************************************************
# solving non linear poisson equation
#
#  newton iteration: 1, reldVnorm = 1.000000
#
#  damping iteration: 1, residual norm = 216014022.171078
#
#  damping iteration: 2, residual norm = 216014023.383506
#
#  damping iteration: 3, residual norm = 216014022.413580
#
#  damping iteration: 4, residual norm = 216014022.219169
#
#  damping iteration: 5, residual norm = 216014022.179468
#
#  damping iteration: 6, residual norm = 216014022.172347
#
#  damping iteration: 7, residual norm = 216014022.170510
#
#  damping iteration: 8, residual norm = 216014022.170142
#
#  damping iteration: 9, residual norm = 216014022.170069
#
# exiting newton cycle because reldVnorm= 0.000000
#
# updating electron qfl
# updating hole qfl
# checking for convergence
# max(|phin_(k+1)-phin_(k)| , |phip_(k+1)-phip_(k)| , |v_(k+1)- v_(k)|) = 26.237750149071438
# *****************************************************************
# ****    start of gummel iteration number: 3
# *****************************************************************
# solving non linear poisson equation
#
#  newton iteration: 1, reldVnorm = 1.000000
#
#  damping iteration: 1, residual norm = 45582407002.705696
#
#  damping iteration: 2, residual norm = 380391727.408209
#
# exiting damping cycle
#
#
#  newton iteration: 2, reldVnorm = 0.056544
#
#  damping iteration: 1, residual norm = 380391727.408209
#
#  damping iteration: 2, residual norm = 36465621141.539185
#
# exiting damping cycle
#
#
#  newton iteration: 3, reldVnorm = 0.002910
#
#  damping iteration: 1, residual norm = 36465621141.539185
#
# exiting damping cycle because residual norm = 304313178.348876
#
#
#  newton iteration: 4, reldVnorm = 0.235844
#
#  damping iteration: 1, residual norm = 304313178.348876
#
# exiting damping cycle because residual norm = 110.414942
#
#
#  newton iteration: 5, reldVnorm = 0.012138
#
#  damping iteration: 1, residual norm = 110.414942
#
# exiting damping cycle because residual norm = 0.069380
#
#
# exiting newton cycle because reldVnorm= 0.000000
#
# updating electron qfl
# updating hole qfl
# checking for convergence
# max(|phin_(k+1)-phin_(k)| , |phip_(k+1)-phip_(k)| , |v_(k+1)- v_(k)|) = 25.478197406032507
# *****************************************************************
# ****    start of gummel iteration number: 4
# *****************************************************************
# solving non linear poisson equation
#
#  newton iteration: 1, reldVnorm = 1.000000
#
#  damping iteration: 1, residual norm = 25835716.984572
#
#  damping iteration: 2, residual norm = 25835653.234397
#
# exiting damping cycle
#
#
#  newton iteration: 2, reldVnorm = 0.039318
#
#  damping iteration: 1, residual norm = 25835653.234397
#
# exiting damping cycle because residual norm = 20668573.524319
#
#
#  newton iteration: 3, reldVnorm = 0.001030
#
#  damping iteration: 1, residual norm = 20668573.524319
#
# exiting damping cycle because residual norm = 41.516760
#
#
#  newton iteration: 4, reldVnorm = 0.157252
#
#  damping iteration: 1, residual norm = 41.516760
#
# exiting damping cycle because residual norm = 0.000629
#
#
# exiting newton cycle because reldVnorm= 0.000010
#
# updating electron qfl
# updating hole qfl
# checking for convergence
# max(|phin_(k+1)-phin_(k)| , |phip_(k+1)-phip_(k)| , |v_(k+1)- v_(k)|) = 25.04527991493609
# *****************************************************************
# ****    start of gummel iteration number: 5
# *****************************************************************
# solving non linear poisson equation
#
#  newton iteration: 1, reldVnorm = 1.000000
#
#  damping iteration: 1, residual norm = 16253430140.421267
#
#  damping iteration: 2, residual norm = 12905618.152907
#
# exiting damping cycle
#
#
#  newton iteration: 2, reldVnorm = 0.057082
#
#  damping iteration: 1, residual norm = 12905618.152907
#
#  damping iteration: 2, residual norm = 13002711135.870087
#
# exiting damping cycle
#
#
#  newton iteration: 3, reldVnorm = 0.000104
#
#  damping iteration: 1, residual norm = 13002711135.870087
#
# exiting damping cycle because residual norm = 10324494.514356
#
#
#  newton iteration: 4, reldVnorm = 0.233860
#
#  damping iteration: 1, residual norm = 10324494.514356
#
# exiting damping cycle because residual norm = 0.043757
#
#
#  newton iteration: 5, reldVnorm = 0.000424
#
#  damping iteration: 1, residual norm = 0.043757
#
# exiting damping cycle because residual norm = 0.038765
#
#
# exiting newton cycle because reldVnorm= 0.000000
#
# updating electron qfl
# updating hole qfl
# checking for convergence
# max(|phin_(k+1)-phin_(k)| , |phip_(k+1)-phip_(k)| , |v_(k+1)- v_(k)|) = 24.60730018953152
# *****************************************************************
# ****    start of gummel iteration number: 6
# *****************************************************************
# solving non linear poisson equation
#
#  newton iteration: 1, reldVnorm = 1.000000
#
#  damping iteration: 1, residual norm = 6464700.424208
#
#  damping iteration: 2, residual norm = 6464684.489822
#
# exiting damping cycle
#
#
#  newton iteration: 2, reldVnorm = 0.047904
#
#  damping iteration: 1, residual norm = 6464684.489822
#
# exiting damping cycle because residual norm = 5171760.337502
#
#
#  newton iteration: 3, reldVnorm = 0.000266
#
#  damping iteration: 1, residual norm = 5171760.337502
#
# exiting damping cycle because residual norm = 105.089311
#
#
#  newton iteration: 4, reldVnorm = 0.191588
#
#  damping iteration: 1, residual norm = 105.089311
#
# exiting damping cycle because residual norm = 0.000751
#
#
#  newton iteration: 5, reldVnorm = 0.000016
#
#  damping iteration: 1, residual norm = 0.000751
#
#  damping iteration: 2, residual norm = 0.001314
#
# exiting damping cycle because residual norm = 0.000751
#
#
# exiting newton cycle because reldVnorm= 0.000000
#
# updating electron qfl
# updating hole qfl
# checking for convergence
# max(|phin_(k+1)-phin_(k)| , |phip_(k+1)-phip_(k)| , |v_(k+1)- v_(k)|) = 24.303714469741916
# *****************************************************************
# ****    start of gummel iteration number: 7
# *****************************************************************
# solving non linear poisson equation
#
#  newton iteration: 1, reldVnorm = 1.000000
#
#  damping iteration: 1, residual norm = 7233638072.665115
#
#  damping iteration: 2, residual norm = 3223396.020466
#
# exiting damping cycle
#
#
#  newton iteration: 2, reldVnorm = 0.055194
#
#  damping iteration: 1, residual norm = 3223396.020466
#
#  damping iteration: 2, residual norm = 5786905106.838229
#
# exiting damping cycle
#
#
#  newton iteration: 3, reldVnorm = 0.000027
#
#  damping iteration: 1, residual norm = 5786905106.838229
#
# exiting damping cycle because residual norm = 2578716.817820
#
#
#  newton iteration: 4, reldVnorm = 0.224057
#
#  damping iteration: 1, residual norm = 2578716.817820
#
# exiting damping cycle because residual norm = 0.031187
#
#
#  newton iteration: 5, reldVnorm = 0.000108
#
#  damping iteration: 1, residual norm = 0.031187
#
#  damping iteration: 2, residual norm = 0.032686
#
# exiting damping cycle because residual norm = 0.023449
#
#
# exiting newton cycle because reldVnorm= 0.000000
#
# updating electron qfl
# updating hole qfl
# checking for convergence
# max(|phin_(k+1)-phin_(k)| , |phip_(k+1)-phip_(k)| , |v_(k+1)- v_(k)|) = 23.9970741737363
# *****************************************************************
# ****    start of gummel iteration number: 8
# *****************************************************************
# solving non linear poisson equation
#
#  newton iteration: 1, reldVnorm = 1.000000
#
#  damping iteration: 1, residual norm = 2386221.818651
#
#  damping iteration: 2, residual norm = 1620623.535177
#
# exiting damping cycle
#
#
#  newton iteration: 2, reldVnorm = 0.051947
#
#  damping iteration: 1, residual norm = 1620623.535177
#
#  damping iteration: 2, residual norm = 1908757.384734
#
# exiting damping cycle
#
#
#  newton iteration: 3, reldVnorm = 0.000014
#
#  damping iteration: 1, residual norm = 1908757.384734
#
# exiting damping cycle because residual norm = 1296498.828377
#
#
#  newton iteration: 4, reldVnorm = 0.207758
#
#  damping iteration: 1, residual norm = 1296498.828377
#
# exiting damping cycle because residual norm = 0.001052
#
#
#  newton iteration: 5, reldVnorm = 0.000054
#
#  damping iteration: 1, residual norm = 0.001052
#
# exiting damping cycle because residual norm = 0.001012
#
#
# exiting newton cycle because reldVnorm= 0.000000
#
# updating electron qfl
# updating hole qfl
# checking for convergence
# max(|phin_(k+1)-phin_(k)| , |phip_(k+1)-phip_(k)| , |v_(k+1)- v_(k)|) = 23.763562305027406
# *****************************************************************
# ****    start of gummel iteration number: 9
# *****************************************************************
# solving non linear poisson equation
#
#  newton iteration: 1, reldVnorm = 1.000000
#
#  damping iteration: 1, residual norm = 3690450275.123148
#
#  damping iteration: 2, residual norm = 803144.600334
#
# exiting damping cycle
#
#
#  newton iteration: 2, reldVnorm = 0.056003
#
#  damping iteration: 1, residual norm = 803144.600334
#
#  damping iteration: 2, residual norm = 2952359084.298291
#
# exiting damping cycle
#
#
# exiting newton cycle because reldVnorm= 0.000010
#
# updating electron qfl
# updating hole qfl
# checking for convergence
# max(|phin_(k+1)-phin_(k)| , |phip_(k+1)-phip_(k)| , |v_(k+1)- v_(k)|) = 23.528081985828123
# *****************************************************************
# ****    start of gummel iteration number: 10
# *****************************************************************
# solving non linear poisson equation
#
#  newton iteration: 1, reldVnorm = 1.000000
#
#  damping iteration: 1, residual norm = 1178149.793182
#
#  damping iteration: 2, residual norm = 1178146.757989
#
# exiting damping cycle
#
#
#  newton iteration: 2, reldVnorm = 0.095581
#
#  damping iteration: 1, residual norm = 1178146.757989
#
# exiting damping cycle because residual norm = 942519.833997
#
#
#  newton iteration: 3, reldVnorm = 0.000241
#
#  damping iteration: 1, residual norm = 942519.833997
#
# exiting damping cycle because residual norm = 7.690420
#
#
#  newton iteration: 4, reldVnorm = 0.385174
#
#  damping iteration: 1, residual norm = 7.690420
#
# exiting damping cycle because residual norm = 0.001452
#
#
#  newton iteration: 5, reldVnorm = 0.000124
#
#  damping iteration: 1, residual norm = 0.001452
#
# exiting damping cycle because residual norm = 0.000613
#
#
# exiting newton cycle because reldVnorm= 0.000000
#
# updating electron qfl
# updating hole qfl
# checking for convergence
# max(|phin_(k+1)-phin_(k)| , |phip_(k+1)-phip_(k)| , |v_(k+1)- v_(k)|) = 23.338428106888493
# *****************************************************************
# ****    start of gummel iteration number: 11
# *****************************************************************
# solving non linear poisson equation
#
#  newton iteration: 1, reldVnorm = 1.000000
#
#  damping iteration: 1, residual norm = 2068568636.794728
#
#  damping iteration: 2, residual norm = 134841.945414
#
# exiting damping cycle
#
#
#  newton iteration: 2, reldVnorm = 0.039377
#
#  damping iteration: 1, residual norm = 134841.945414
#
#  damping iteration: 2, residual norm = 1654854616.757922
#
# exiting damping cycle
#
#
# exiting newton cycle because reldVnorm= 0.000003
#
# updating electron qfl
# updating hole qfl
# checking for convergence
# max(|phin_(k+1)-phin_(k)| , |phip_(k+1)-phip_(k)| , |v_(k+1)- v_(k)|) = 23.14744098461622
# *****************************************************************
# ****    start of gummel iteration number: 12
# *****************************************************************
# solving non linear poisson equation
#
#  newton iteration: 1, reldVnorm = 1.000000
#
#  damping iteration: 1, residual norm = 403326.033895
#
#  damping iteration: 2, residual norm = 198344.058792
#
# exiting damping cycle
#
#
#  newton iteration: 2, reldVnorm = 0.016402
#
#  damping iteration: 1, residual norm = 198344.058792
#
#  damping iteration: 2, residual norm = 322660.802995
#
# exiting damping cycle
#
#
# exiting newton cycle because reldVnorm= 0.000002
#
# updating electron qfl
# updating hole qfl
# checking for convergence
# max(|phin_(k+1)-phin_(k)| , |phip_(k+1)-phip_(k)| , |v_(k+1)- v_(k)|) = 22.987828365384942
# *****************************************************************
# ****    start of gummel iteration number: 13
# *****************************************************************
# solving non linear poisson equation
#
#  newton iteration: 1, reldVnorm = 1.000000
#
#  damping iteration: 1, residual norm = 2034867180.550223
#
#  damping iteration: 2, residual norm = 216016.498324
#
# exiting damping cycle
#
#
#  newton iteration: 2, reldVnorm = 0.032204
#
#  damping iteration: 1, residual norm = 216016.498324
#
#  damping iteration: 2, residual norm = 1627893360.807461
#
# exiting damping cycle
#
#
# exiting newton cycle because reldVnorm= 0.000002
#
# updating electron qfl
# updating hole qfl
# checking for convergence
# max(|phin_(k+1)-phin_(k)| , |phip_(k+1)-phip_(k)| , |v_(k+1)- v_(k)|) = 22.827527319522183
# *****************************************************************
# ****    start of gummel iteration number: 14
# *****************************************************************
# solving non linear poisson equation
#
#  newton iteration: 1, reldVnorm = 1.000000
#
#  damping iteration: 1, residual norm = 987209.161774
#
#  damping iteration: 2, residual norm = 209082.611996
#
# exiting damping cycle
#
#
#  newton iteration: 2, reldVnorm = 0.025159
#
#  damping iteration: 1, residual norm = 209082.611996
#
#  damping iteration: 2, residual norm = 789752.323112
#
# exiting damping cycle
#
#
# exiting newton cycle because reldVnorm= 0.000002
#
# updating electron qfl
# updating hole qfl
# checking for convergence
# max(|phin_(k+1)-phin_(k)| , |phip_(k+1)-phip_(k)| , |v_(k+1)- v_(k)|) = 22.68978807163468
# *****************************************************************
# ****    start of gummel iteration number: 15
# *****************************************************************
# solving non linear poisson equation
#
#  newton iteration: 1, reldVnorm = 1.000000
#
#  damping iteration: 1, residual norm = 1668516722.585485
#
#  damping iteration: 2, residual norm = 188488.482346
#
# exiting damping cycle
#
#
#  newton iteration: 2, reldVnorm = 0.017027
#
#  damping iteration: 1, residual norm = 188488.482346
#
#  damping iteration: 2, residual norm = 1334813099.372505
#
# exiting damping cycle
#
#
# exiting newton cycle because reldVnorm= 0.000002
#
# updating electron qfl
# updating hole qfl
# checking for convergence
# max(|phin_(k+1)-phin_(k)| , |phip_(k+1)-phip_(k)| , |v_(k+1)- v_(k)|) = 22.55158360277173
# *****************************************************************
# ****    start of gummel iteration number: 16
# *****************************************************************
# solving non linear poisson equation
#
#  newton iteration: 1, reldVnorm = 1.000000
#
#  damping iteration: 1, residual norm = 1616385.176053
#
#  damping iteration: 2, residual norm = 162967.344047
#
# exiting damping cycle
#
#
#  newton iteration: 2, reldVnorm = 0.046164
#
#  damping iteration: 1, residual norm = 162967.344047
#
#  damping iteration: 2, residual norm = 1293042.943821
#
# exiting damping cycle
#
#
# exiting newton cycle because reldVnorm= 0.000005
#
# updating electron qfl
# updating hole qfl
# checking for convergence
# max(|phin_(k+1)-phin_(k)| , |phip_(k+1)-phip_(k)| , |v_(k+1)- v_(k)|) = 22.430461397107678
# *****************************************************************
# ****    start of gummel iteration number: 17
# *****************************************************************
# solving non linear poisson equation
#
#  newton iteration: 1, reldVnorm = 1.000000
#
#  damping iteration: 1, residual norm = 1315448739.945698
#
#  damping iteration: 2, residual norm = 136254.609016
#
# exiting damping cycle
#
#
#  newton iteration: 2, reldVnorm = 0.014033
#
#  damping iteration: 1, residual norm = 136254.609016
#
#  damping iteration: 2, residual norm = 1052358817.874739
#
# exiting damping cycle
#
#
# exiting newton cycle because reldVnorm= 0.000001
#
# updating electron qfl
# updating hole qfl
# checking for convergence
# max(|phin_(k+1)-phin_(k)| , |phip_(k+1)-phip_(k)| , |v_(k+1)- v_(k)|) = 22.308975827188952
# *****************************************************************
# ****    start of gummel iteration number: 18
# *****************************************************************
# solving non linear poisson equation
#
#  newton iteration: 1, reldVnorm = 1.000000
#
#  damping iteration: 1, residual norm = 2085380.880788
#
#  damping iteration: 2, residual norm = 110672.522052
#
# exiting damping cycle
#
#
#  newton iteration: 2, reldVnorm = 0.067487
#
#  damping iteration: 1, residual norm = 110672.522052
#
#  damping iteration: 2, residual norm = 1668165.998075
#
# exiting damping cycle
#
#
#  newton iteration: 3, reldVnorm = 0.000016
#
#  damping iteration: 1, residual norm = 1668165.998075
#
# exiting damping cycle because residual norm = 88538.018146
#
#
#  newton iteration: 4, reldVnorm = 0.271311
#
#  damping iteration: 1, residual norm = 88538.018146
#
# exiting damping cycle because residual norm = 0.001524
#
#
#  newton iteration: 5, reldVnorm = 0.000108
#
#  damping iteration: 1, residual norm = 0.001524
#
# exiting damping cycle because residual norm = 0.000541
#
#
# exiting newton cycle because reldVnorm= 0.000000
#
# updating electron qfl
# updating hole qfl
# checking for convergence
# max(|phin_(k+1)-phin_(k)| , |phip_(k+1)-phip_(k)| , |v_(k+1)- v_(k)|) = 22.200901717392544
# *****************************************************************
# ****    start of gummel iteration number: 19
# *****************************************************************
# solving non linear poisson equation
#
#  newton iteration: 1, reldVnorm = 1.000000
#
#  damping iteration: 1, residual norm = 455661816.320895
#
#  damping iteration: 2, residual norm = 42496.031393
#
# exiting damping cycle
#
#
#  newton iteration: 2, reldVnorm = 0.065447
#
#  damping iteration: 1, residual norm = 42496.031393
#
#  damping iteration: 2, residual norm = 364529444.079774
#
# exiting damping cycle
#
#
#  newton iteration: 3, reldVnorm = 0.000015
#
#  damping iteration: 1, residual norm = 364529444.079774
#
# exiting damping cycle because residual norm = 36838.828489
#
#
#  newton iteration: 4, reldVnorm = 0.262410
#
#  damping iteration: 1, residual norm = 36838.828489
#
# exiting damping cycle because residual norm = 0.011936
#
#
#  newton iteration: 5, reldVnorm = 0.000097
#
#  damping iteration: 1, residual norm = 0.011936
#
# exiting damping cycle because residual norm = 0.011936
#
#
# exiting newton cycle because reldVnorm= 0.000000
#
# updating electron qfl
# updating hole qfl
# checking for convergence
# max(|phin_(k+1)-phin_(k)| , |phip_(k+1)-phip_(k)| , |v_(k+1)- v_(k)|) = 22.09233148556934
# *****************************************************************
# ****    start of gummel iteration number: 20
# *****************************************************************
# solving non linear poisson equation
#
#  newton iteration: 1, reldVnorm = 1.000000
#
#  damping iteration: 1, residual norm = 1671025.969740
#
#  damping iteration: 2, residual norm = 17764.942679
#
# exiting damping cycle
#
#
#  newton iteration: 2, reldVnorm = 0.056140
#
#  damping iteration: 1, residual norm = 17764.942679
#
#  damping iteration: 2, residual norm = 1336749.964907
#
# exiting damping cycle
#
#
# exiting newton cycle because reldVnorm= 0.000009
#
# updating electron qfl
# updating hole qfl
# checking for convergence
# max(|phin_(k+1)-phin_(k)| , |phip_(k+1)-phip_(k)| , |v_(k+1)- v_(k)|) = 21.994750249287023
# *****************************************************************
# ****    start of gummel iteration number: 21
# *****************************************************************
# solving non linear poisson equation
#
#  newton iteration: 1, reldVnorm = 1.000000
#
#  damping iteration: 1, residual norm = 321245029.714524
#
#  damping iteration: 2, residual norm = 27343.025671
#
# exiting damping cycle
#
#
#  newton iteration: 2, reldVnorm = 0.022016
#
#  damping iteration: 1, residual norm = 27343.025671
#
#  damping iteration: 2, residual norm = 256996019.949130
#
# exiting damping cycle
#
#
# exiting newton cycle because reldVnorm= 0.000001
#
# updating electron qfl
# updating hole qfl
# checking for convergence
# max(|phin_(k+1)-phin_(k)| , |phip_(k+1)-phip_(k)| , |v_(k+1)- v_(k)|) = 21.896780620559664
# *****************************************************************
# ****    start of gummel iteration number: 22
# *****************************************************************
# solving non linear poisson equation
#
#  newton iteration: 1, reldVnorm = 1.000000
#
#  damping iteration: 1, residual norm = 2192681.930771
#
#  damping iteration: 2, residual norm = 29443.326829
#
# exiting damping cycle
#
#
#  newton iteration: 2, reldVnorm = 0.065595
#
#  damping iteration: 1, residual norm = 29443.326829
#
#  damping iteration: 2, residual norm = 1753986.873069
#
# exiting damping cycle
#
#
#  newton iteration: 3, reldVnorm = 0.000015
#
#  damping iteration: 1, residual norm = 1753986.873069
#
# exiting damping cycle because residual norm = 23554.661780
#
#
#  newton iteration: 4, reldVnorm = 0.262749
#
#  damping iteration: 1, residual norm = 23554.661780
#
# exiting damping cycle because residual norm = 0.000325
#
#
#  newton iteration: 5, reldVnorm = 0.000097
#
#  damping iteration: 1, residual norm = 0.000325
#
#  damping iteration: 2, residual norm = 0.000325
#
#  damping iteration: 3, residual norm = 0.000325
#
#  damping iteration: 4, residual norm = 0.000325
#
#  damping iteration: 5, residual norm = 0.000325
#
#  damping iteration: 6, residual norm = 0.000325
#
#  damping iteration: 7, residual norm = 0.000325
#
#  damping iteration: 8, residual norm = 0.000325
#
#  damping iteration: 9, residual norm = 0.000325
#
# exiting newton cycle because reldVnorm= 0.000000
#
# updating electron qfl
# updating hole qfl
# checking for convergence
# max(|phin_(k+1)-phin_(k)| , |phip_(k+1)-phip_(k)| , |v_(k+1)- v_(k)|) = 21.807841463170515
# *****************************************************************
# ****    start of gummel iteration number: 23
# *****************************************************************
# solving non linear poisson equation
#
#  newton iteration: 1, reldVnorm = 1.000000
#
#  damping iteration: 1, residual norm = 235591111.917467
#
#  damping iteration: 2, residual norm = 34618.314456
#
# exiting damping cycle
#
#
#  newton iteration: 2, reldVnorm = 0.070974
#
#  damping iteration: 1, residual norm = 34618.314456
#
#  damping iteration: 2, residual norm = 188472887.728525
#
# exiting damping cycle
#
#
#  newton iteration: 3, reldVnorm = 0.000019
#
#  damping iteration: 1, residual norm = 188472887.728525
#
# exiting damping cycle because residual norm = 45411.778081
#
#
#  newton iteration: 4, reldVnorm = 0.284298
#
#  damping iteration: 1, residual norm = 45411.778081
#
# exiting damping cycle because residual norm = 0.009796
#
#
#  newton iteration: 5, reldVnorm = 0.000122
#
#  damping iteration: 1, residual norm = 0.009796
#
# exiting damping cycle because residual norm = 0.009796
#
#
# exiting newton cycle because reldVnorm= 0.000000
#
# updating electron qfl
# updating hole qfl
# checking for convergence
# max(|phin_(k+1)-phin_(k)| , |phip_(k+1)-phip_(k)| , |v_(k+1)- v_(k)|) = 21.71859402297237
# *****************************************************************
# ****    start of gummel iteration number: 24
# *****************************************************************
# solving non linear poisson equation
#
#  newton iteration: 1, reldVnorm = 1.000000
#
#  damping iteration: 1, residual norm = 1474840.788596
#
#  damping iteration: 2, residual norm = 2161.962792
#
# exiting damping cycle
#
#
#  newton iteration: 2, reldVnorm = 0.051941
#
#  damping iteration: 1, residual norm = 2161.962792
#
#  damping iteration: 2, residual norm = 1179824.651675
#
# exiting damping cycle
#
#
# exiting newton cycle because reldVnorm= 0.000007
#
# updating electron qfl
# updating hole qfl
# checking for convergence
# max(|phin_(k+1)-phin_(k)| , |phip_(k+1)-phip_(k)| , |v_(k+1)- v_(k)|) = 21.636894661926057
# *****************************************************************
# ****    start of gummel iteration number: 25
# *****************************************************************
# solving non linear poisson equation
#
#  newton iteration: 1, reldVnorm = 1.000000
#
#  damping iteration: 1, residual norm = 173799371.404821
#
#  damping iteration: 2, residual norm = 4763.119817
#
# exiting damping cycle
#
#
#  newton iteration: 2, reldVnorm = 0.019889
#
#  damping iteration: 1, residual norm = 4763.119817
#
#  damping iteration: 2, residual norm = 139039496.269809
#
# exiting damping cycle
#
#
# exiting newton cycle because reldVnorm= 0.000000
#
# updating electron qfl
# updating hole qfl
# checking for convergence
# max(|phin_(k+1)-phin_(k)| , |phip_(k+1)-phip_(k)| , |v_(k+1)- v_(k)|) = 21.55494617297291
# *****************************************************************
# ****    start of gummel iteration number: 26
# *****************************************************************
# solving non linear poisson equation
#
#  newton iteration: 1, reldVnorm = 1.000000
#
#  damping iteration: 1, residual norm = 1851590.225708
#
#  damping iteration: 2, residual norm = 7998.801336
#
# exiting damping cycle
#
#
#  newton iteration: 2, reldVnorm = 0.055887
#
#  damping iteration: 1, residual norm = 7998.801336
#
#  damping iteration: 2, residual norm = 1481177.909212
#
# exiting damping cycle
#
#
# exiting newton cycle because reldVnorm= 0.000009
#
# updating electron qfl
# updating hole qfl
# checking for convergence
# max(|phin_(k+1)-phin_(k)| , |phip_(k+1)-phip_(k)| , |v_(k+1)- v_(k)|) = 21.47939730656266
# *****************************************************************
# ****    start of gummel iteration number: 27
# *****************************************************************
# solving non linear poisson equation
#
#  newton iteration: 1, reldVnorm = 1.000000
#
#  damping iteration: 1, residual norm = 216216573.593885
#
#  damping iteration: 2, residual norm = 11071.172790
#
# exiting damping cycle
#
#
#  newton iteration: 2, reldVnorm = 0.023588
#
#  damping iteration: 1, residual norm = 11071.172790
#
#  damping iteration: 2, residual norm = 172973256.962000
#
# exiting damping cycle
#
#
# exiting newton cycle because reldVnorm= 0.000001
#
# updating electron qfl
# updating hole qfl
# checking for convergence
# max(|phin_(k+1)-phin_(k)| , |phip_(k+1)-phip_(k)| , |v_(k+1)- v_(k)|) = 21.40367375778259
# *****************************************************************
# ****    start of gummel iteration number: 28
# *****************************************************************
# solving non linear poisson equation
#
#  newton iteration: 1, reldVnorm = 1.000000
#
#  damping iteration: 1, residual norm = 1631753.291101
#
#  damping iteration: 2, residual norm = 13235.221579
#
# exiting damping cycle
#
#
#  newton iteration: 2, reldVnorm = 0.049556
#
#  damping iteration: 1, residual norm = 13235.221579
#
#  damping iteration: 2, residual norm = 1305338.505636
#
# exiting damping cycle
#
#
# exiting newton cycle because reldVnorm= 0.000006
#
# updating electron qfl
# updating hole qfl
# checking for convergence
# max(|phin_(k+1)-phin_(k)| , |phip_(k+1)-phip_(k)| , |v_(k+1)- v_(k)|) = 21.333418582204057
# *****************************************************************
# ****    start of gummel iteration number: 29
# *****************************************************************
# solving non linear poisson equation
#
#  newton iteration: 1, reldVnorm = 1.000000
#
#  damping iteration: 1, residual norm = 210701932.120153
#
#  damping iteration: 2, residual norm = 13352.151357
#
# exiting damping cycle
#
#
#  newton iteration: 2, reldVnorm = 0.026538
#
#  damping iteration: 1, residual norm = 13352.151357
#
#  damping iteration: 2, residual norm = 168561543.660446
#
# exiting damping cycle
#
#
# exiting newton cycle because reldVnorm= 0.000001
#
# updating electron qfl
# updating hole qfl
# checking for convergence
# max(|phin_(k+1)-phin_(k)| , |phip_(k+1)-phip_(k)| , |v_(k+1)- v_(k)|) = 21.26302808046473
# *****************************************************************
# ****    start of gummel iteration number: 30
# *****************************************************************
# solving non linear poisson equation
#
#  newton iteration: 1, reldVnorm = 1.000000
#
#  damping iteration: 1, residual norm = 1091737.882093
#
#  damping iteration: 2, residual norm = 11312.308882
#
# exiting damping cycle
#
#
#  newton iteration: 2, reldVnorm = 0.033678
#
#  damping iteration: 1, residual norm = 11312.308882
#
#  damping iteration: 2, residual norm = 873371.205411
#
# exiting damping cycle
#
#
# exiting newton cycle because reldVnorm= 0.000002
#
# updating electron qfl
# updating hole qfl
# checking for convergence
# max(|phin_(k+1)-phin_(k)| , |phip_(k+1)-phip_(k)| , |v_(k+1)- v_(k)|) = 21.197375133916637
# *****************************************************************
# ****    start of gummel iteration number: 31
# *****************************************************************
# solving non linear poisson equation
#
#  newton iteration: 1, reldVnorm = 1.000000
#
#  damping iteration: 1, residual norm = 189513898.845381
#
#  damping iteration: 2, residual norm = 6578.315117
#
# exiting damping cycle
#
#
#  newton iteration: 2, reldVnorm = 0.033705
#
#  damping iteration: 1, residual norm = 6578.315117
#
#  damping iteration: 2, residual norm = 151611117.385606
#
# exiting damping cycle
#
#
# exiting newton cycle because reldVnorm= 0.000002
#
# updating electron qfl
# updating hole qfl
# checking for convergence
# max(|phin_(k+1)-phin_(k)| , |phip_(k+1)-phip_(k)| , |v_(k+1)- v_(k)|) = 21.131610415522342
# *****************************************************************
# ****    start of gummel iteration number: 32
# *****************************************************************
# solving non linear poisson equation
#
#  newton iteration: 1, reldVnorm = 1.000000
#
#  damping iteration: 1, residual norm = 464641.603197
#
#  damping iteration: 2, residual norm = 366.323182
#
# exiting damping cycle
#
#
#  newton iteration: 2, reldVnorm = 0.013473
#
#  damping iteration: 1, residual norm = 366.323182
#
#  damping iteration: 2, residual norm = 371711.817526
#
# exiting damping cycle
#
#
# exiting newton cycle because reldVnorm= 0.000000
#
# updating electron qfl
# updating hole qfl
# checking for convergence
# max(|phin_(k+1)-phin_(k)| , |phip_(k+1)-phip_(k)| , |v_(k+1)- v_(k)|) = 21.069994538826336
# *****************************************************************
# ****    start of gummel iteration number: 33
# *****************************************************************
# solving non linear poisson equation
#
#  newton iteration: 1, reldVnorm = 1.000000
#
#  damping iteration: 1, residual norm = 165048143.738646
#
#  damping iteration: 2, residual norm = 7275.653415
#
# exiting damping cycle
#
#
#  newton iteration: 2, reldVnorm = 0.045260
#
#  damping iteration: 1, residual norm = 7275.653415
#
#  damping iteration: 2, residual norm = 132038513.727883
#
# exiting damping cycle
#
#
# exiting newton cycle because reldVnorm= 0.000005
#
# updating electron qfl
# updating hole qfl
# checking for convergence
# max(|phin_(k+1)-phin_(k)| , |phip_(k+1)-phip_(k)| , |v_(k+1)- v_(k)|) = 21.008282813080427
# *****************************************************************
# ****    start of gummel iteration number: 34
# *****************************************************************
# solving non linear poisson equation
#
#  newton iteration: 1, reldVnorm = 1.000000
#
#  damping iteration: 1, residual norm = 322277.869112
#
#  damping iteration: 2, residual norm = 14247.727045
#
# exiting damping cycle
#
#
#  newton iteration: 2, reldVnorm = 0.024100
#
#  damping iteration: 1, residual norm = 14247.727045
#
#  damping iteration: 2, residual norm = 257822.283050
#
# exiting damping cycle
#
#
# exiting newton cycle because reldVnorm= 0.000001
#
# updating electron qfl
# updating hole qfl
# checking for convergence
# max(|phin_(k+1)-phin_(k)| , |phip_(k+1)-phip_(k)| , |v_(k+1)- v_(k)|) = 20.950236469704258
# *****************************************************************
# ****    start of gummel iteration number: 35
# *****************************************************************
# solving non linear poisson equation
#
#  newton iteration: 1, reldVnorm = 1.000000
#
#  damping iteration: 1, residual norm = 141846257.681336
#
#  damping iteration: 2, residual norm = 20518.094130
#
# exiting damping cycle
#
#
#  newton iteration: 2, reldVnorm = 0.058956
#
#  damping iteration: 1, residual norm = 20518.094130
#
#  damping iteration: 2, residual norm = 113477005.248151
#
# exiting damping cycle
#
#
#  newton iteration: 3, reldVnorm = 0.000011
#
#  damping iteration: 1, residual norm = 113477005.248151
#
# exiting damping cycle because residual norm = 16414.475140
#
#
#  newton iteration: 4, reldVnorm = 0.236139
#
#  damping iteration: 1, residual norm = 16414.475140
#
# exiting damping cycle because residual norm = 0.006150
#
#
#  newton iteration: 5, reldVnorm = 0.000069
#
#  damping iteration: 1, residual norm = 0.006150
#
#  damping iteration: 2, residual norm = 0.006150
#
#  damping iteration: 3, residual norm = 0.006150
#
#  damping iteration: 4, residual norm = 0.006150
#
# exiting damping cycle because residual norm = 0.006150
#
#
# exiting newton cycle because reldVnorm= 0.000000
#
# updating electron qfl
# updating hole qfl
# checking for convergence
# max(|phin_(k+1)-phin_(k)| , |phip_(k+1)-phip_(k)| , |v_(k+1)- v_(k)|) = 20.89210617506346
# *****************************************************************
# ****    start of gummel iteration number: 36
# *****************************************************************
# solving non linear poisson equation
#
#  newton iteration: 1, reldVnorm = 1.000000
#
#  damping iteration: 1, residual norm = 1617638.919213
#
#  damping iteration: 2, residual norm = 7485.607380
#
# exiting damping cycle
#
#
#  newton iteration: 2, reldVnorm = 0.069444
#
#  damping iteration: 1, residual norm = 7485.607380
#
#  damping iteration: 2, residual norm = 1294049.784250
#
# exiting damping cycle
#
#
#  newton iteration: 3, reldVnorm = 0.000017
#
#  damping iteration: 1, residual norm = 1294049.784250
#
# exiting damping cycle because residual norm = 5988.485999
#
#
#  newton iteration: 4, reldVnorm = 0.277727
#
#  damping iteration: 1, residual norm = 5988.485999
#
# exiting damping cycle because residual norm = 0.001655
#
#
#  newton iteration: 5, reldVnorm = 0.000113
#
#  damping iteration: 1, residual norm = 0.001655
#
# exiting damping cycle because residual norm = 0.000441
#
#
# exiting newton cycle because reldVnorm= 0.000000
#
# updating electron qfl
# updating hole qfl
# checking for convergence
# max(|phin_(k+1)-phin_(k)| , |phip_(k+1)-phip_(k)| , |v_(k+1)- v_(k)|) = 20.83724030082972
# *****************************************************************
# ****    start of gummel iteration number: 37
# *****************************************************************
# solving non linear poisson equation
#
#  newton iteration: 1, reldVnorm = 1.000000
#
#  damping iteration: 1, residual norm = 96562175.003079
#
#  damping iteration: 2, residual norm = 8334.477948
#
# exiting damping cycle
#
#
#  newton iteration: 2, reldVnorm = 0.049752
#
#  damping iteration: 1, residual norm = 8334.477948
#
#  damping iteration: 2, residual norm = 77246668.127099
#
# exiting damping cycle
#
#
# exiting newton cycle because reldVnorm= 0.000006
#
# updating electron qfl
# updating hole qfl
# checking for convergence
# max(|phin_(k+1)-phin_(k)| , |phip_(k+1)-phip_(k)| , |v_(k+1)- v_(k)|) = 20.782274244101096
# *****************************************************************
# ****    start of gummel iteration number: 38
# *****************************************************************
# solving non linear poisson equation
#
#  newton iteration: 1, reldVnorm = 1.000000
#
#  damping iteration: 1, residual norm = 126681.437974
#
#  damping iteration: 2, residual norm = 3653.611549
#
# exiting damping cycle
#
#
#  newton iteration: 2, reldVnorm = 0.039930
#
#  damping iteration: 1, residual norm = 3653.611549
#
#  damping iteration: 2, residual norm = 101345.121089
#
# exiting damping cycle
#
#
# exiting newton cycle because reldVnorm= 0.000003
#
# updating electron qfl
# updating hole qfl
# checking for convergence
# max(|phin_(k+1)-phin_(k)| , |phip_(k+1)-phip_(k)| , |v_(k+1)- v_(k)|) = 20.73025403224745
# *****************************************************************
# ****    start of gummel iteration number: 39
# *****************************************************************
# solving non linear poisson equation
#
#  newton iteration: 1, reldVnorm = 1.000000
#
#  damping iteration: 1, residual norm = 95366933.604186
#
#  damping iteration: 2, residual norm = 9112.694772
#
# exiting damping cycle
#
#
#  newton iteration: 2, reldVnorm = 0.060185
#
#  damping iteration: 1, residual norm = 9112.694772
#
#  damping iteration: 2, residual norm = 76290244.061442
#
# exiting damping cycle
#
#
#  newton iteration: 3, reldVnorm = 0.000011
#
#  damping iteration: 1, residual norm = 76290244.061442
#
# exiting damping cycle because residual norm = 11954.699273
#
#
#  newton iteration: 4, reldVnorm = 0.240887
#
#  damping iteration: 1, residual norm = 11954.699273
#
# exiting damping cycle because residual norm = 0.005396
#
#
#  newton iteration: 5, reldVnorm = 0.000073
#
#  damping iteration: 1, residual norm = 0.005396
#
# exiting damping cycle because residual norm = 0.005396
#
#
# exiting newton cycle because reldVnorm= 0.000000
#
# updating electron qfl
# updating hole qfl
# checking for convergence
# max(|phin_(k+1)-phin_(k)| , |phip_(k+1)-phip_(k)| , |v_(k+1)- v_(k)|) = 20.678156204996412
# *****************************************************************
# ****    start of gummel iteration number: 40
# *****************************************************************
# solving non linear poisson equation
#
#  newton iteration: 1, reldVnorm = 1.000000
#
#  damping iteration: 1, residual norm = 1645414.385496
#
#  damping iteration: 2, residual norm = 1198.537184
#
# exiting damping cycle
#
#
#  newton iteration: 2, reldVnorm = 0.069629
#
#  damping iteration: 1, residual norm = 1198.537184
#
#  damping iteration: 2, residual norm = 1316267.447840
#
# exiting damping cycle
#
#
#  newton iteration: 3, reldVnorm = 0.000017
#
#  damping iteration: 1, residual norm = 1316267.447840
#
# exiting damping cycle because residual norm = 958.830539
#
#
#  newton iteration: 4, reldVnorm = 0.278469
#
#  damping iteration: 1, residual norm = 958.830539
#
# exiting damping cycle because residual norm = 0.000827
#
#
#  newton iteration: 5, reldVnorm = 0.000113
#
#  damping iteration: 1, residual norm = 0.000827
#
#  damping iteration: 2, residual norm = 0.001268
#
#  damping iteration: 3, residual norm = 0.001268
#
# exiting damping cycle because residual norm = 0.000827
#
#
# exiting newton cycle because reldVnorm= 0.000000
#
# updating electron qfl
# updating hole qfl
# checking for convergence
# max(|phin_(k+1)-phin_(k)| , |phip_(k+1)-phip_(k)| , |v_(k+1)- v_(k)|) = 20.628703083593017
# *****************************************************************
# ****    start of gummel iteration number: 41
# *****************************************************************
# solving non linear poisson equation
#
#  newton iteration: 1, reldVnorm = 1.000000
#
#  damping iteration: 1, residual norm = 85688821.673384
#
#  damping iteration: 2, residual norm = 7536.378286
#
# exiting damping cycle
#
#
#  newton iteration: 2, reldVnorm = 0.047840
#
#  damping iteration: 1, residual norm = 7536.378286
#
#  damping iteration: 2, residual norm = 68543942.350489
#
# exiting damping cycle
#
#
# exiting newton cycle because reldVnorm= 0.000006
#
# updating electron qfl
# updating hole qfl
# checking for convergence
# max(|phin_(k+1)-phin_(k)| , |phip_(k+1)-phip_(k)| , |v_(k+1)- v_(k)|) = 20.579174156604616
# *****************************************************************
# ****    start of gummel iteration number: 42
# *****************************************************************
# solving non linear poisson equation
#
#  newton iteration: 1, reldVnorm = 1.000000
#
#  damping iteration: 1, residual norm = 214340.895322
#
#  damping iteration: 2, residual norm = 1607.559990
#
# exiting damping cycle
#
#
#  newton iteration: 2, reldVnorm = 0.037229
#
#  damping iteration: 1, residual norm = 1607.559990
#
#  damping iteration: 2, residual norm = 171472.575450
#
# exiting damping cycle
#
#
# exiting newton cycle because reldVnorm= 0.000003
#
# updating electron qfl
# updating hole qfl
# checking for convergence
# max(|phin_(k+1)-phin_(k)| , |phip_(k+1)-phip_(k)| , |v_(k+1)- v_(k)|) = 20.53204517204809
# *****************************************************************
# ****    start of gummel iteration number: 43
# *****************************************************************
# solving non linear poisson equation
#
#  newton iteration: 1, reldVnorm = 1.000000
#
#  damping iteration: 1, residual norm = 83938688.883905
#
#  damping iteration: 2, residual norm = 7822.725418
#
# exiting damping cycle
#
#
#  newton iteration: 2, reldVnorm = 0.054485
#
#  damping iteration: 1, residual norm = 7822.725418
#
#  damping iteration: 2, residual norm = 67143565.742537
#
# exiting damping cycle
#
#
# exiting newton cycle because reldVnorm= 0.000008
#
# updating electron qfl
# updating hole qfl
# checking for convergence
# max(|phin_(k+1)-phin_(k)| , |phip_(k+1)-phip_(k)| , |v_(k+1)- v_(k)|) = 20.484856190756812
# *****************************************************************
# ****    start of gummel iteration number: 44
# *****************************************************************
# solving non linear poisson equation
#
#  newton iteration: 1, reldVnorm = 1.000000
#
#  damping iteration: 1, residual norm = 296359.282209
#
#  damping iteration: 2, residual norm = 2618.336860
#
# exiting damping cycle
#
#
#  newton iteration: 2, reldVnorm = 0.038355
#
#  damping iteration: 1, residual norm = 2618.336860
#
#  damping iteration: 2, residual norm = 237087.054743
#
# exiting damping cycle
#
#
# exiting newton cycle because reldVnorm= 0.000003
#
# updating electron qfl
# updating hole qfl
# checking for convergence
# max(|phin_(k+1)-phin_(k)| , |phip_(k+1)-phip_(k)| , |v_(k+1)- v_(k)|) = 20.439843455340053
# *****************************************************************
# ****    start of gummel iteration number: 45
# *****************************************************************
# solving non linear poisson equation
#
#  newton iteration: 1, reldVnorm = 1.000000
#
#  damping iteration: 1, residual norm = 67633465.834932
#
#  damping iteration: 2, residual norm = 4755.973231
#
# exiting damping cycle
#
#
#  newton iteration: 2, reldVnorm = 0.050033
#
#  damping iteration: 1, residual norm = 4755.973231
#
#  damping iteration: 2, residual norm = 54102514.654605
#
# exiting damping cycle
#
#
# exiting newton cycle because reldVnorm= 0.000006
#
# updating electron qfl
# updating hole qfl
# checking for convergence
# max(|phin_(k+1)-phin_(k)| , |phip_(k+1)-phip_(k)| , |v_(k+1)- v_(k)|) = 20.394780676415003
# *****************************************************************
# ****    start of gummel iteration number: 46
# *****************************************************************
# solving non linear poisson equation
#
#  newton iteration: 1, reldVnorm = 1.000000
#
#  damping iteration: 1, residual norm = 475538.595213
#
#  damping iteration: 2, residual norm = 1712.248916
#
# exiting damping cycle
#
#
#  newton iteration: 2, reldVnorm = 0.022938
#
#  damping iteration: 1, residual norm = 1712.248916
#
#  damping iteration: 2, residual norm = 380429.347883
#
# exiting damping cycle
#
#
# exiting newton cycle because reldVnorm= 0.000001
#
# updating electron qfl
# updating hole qfl
# checking for convergence
# max(|phin_(k+1)-phin_(k)| , |phip_(k+1)-phip_(k)| , |v_(k+1)- v_(k)|) = 20.351702631656345
# *****************************************************************
# ****    start of gummel iteration number: 47
# *****************************************************************
# solving non linear poisson equation
#
#  newton iteration: 1, reldVnorm = 1.000000
#
#  damping iteration: 1, residual norm = 47710911.739142
#
#  damping iteration: 2, residual norm = 1865.637709
#
# exiting damping cycle
#
#
#  newton iteration: 2, reldVnorm = 0.035763
#
#  damping iteration: 1, residual norm = 1865.637709
#
#  damping iteration: 2, residual norm = 38167088.500552
#
# exiting damping cycle
#
#
# exiting newton cycle because reldVnorm= 0.000002
#
# updating electron qfl
# updating hole qfl
# checking for convergence
# max(|phin_(k+1)-phin_(k)| , |phip_(k+1)-phip_(k)| , |v_(k+1)- v_(k)|) = 20.308581353535196
# *****************************************************************
# ****    start of gummel iteration number: 48
# *****************************************************************
# solving non linear poisson equation
#
#  newton iteration: 1, reldVnorm = 1.000000
#
#  damping iteration: 1, residual norm = 766808.068544
#
#  damping iteration: 2, residual norm = 1420.044279
#
# exiting damping cycle
#
#
#  newton iteration: 2, reldVnorm = 0.024938
#
#  damping iteration: 1, residual norm = 1420.044279
#
#  damping iteration: 2, residual norm = 613440.066059
#
# exiting damping cycle
#
#
# exiting newton cycle because reldVnorm= 0.000001
#
# updating electron qfl
# updating hole qfl
# checking for convergence
# max(|phin_(k+1)-phin_(k)| , |phip_(k+1)-phip_(k)| , |v_(k+1)- v_(k)|) = 20.267278647543357
# *****************************************************************
# ****    start of gummel iteration number: 49
# *****************************************************************
# solving non linear poisson equation
#
#  newton iteration: 1, reldVnorm = 1.000000
#
#  damping iteration: 1, residual norm = 41532424.699651
#
#  damping iteration: 2, residual norm = 3501.134072
#
# exiting damping cycle
#
#
#  newton iteration: 2, reldVnorm = 0.021503
#
#  damping iteration: 1, residual norm = 3501.134072
#
#  damping iteration: 2, residual norm = 33225939.715229
#
# exiting damping cycle
#
#
# exiting newton cycle because reldVnorm= 0.000001
#
# updating electron qfl
# updating hole qfl
# checking for convergence
# max(|phin_(k+1)-phin_(k)| , |phip_(k+1)-phip_(k)| , |v_(k+1)- v_(k)|) = 20.2259377301694
# *****************************************************************
# ****    start of gummel iteration number: 50
# *****************************************************************
# solving non linear poisson equation
#
#  newton iteration: 1, reldVnorm = 1.000000
#
#  damping iteration: 1, residual norm = 1067482.771600
#
# ...
# solving non linear poisson equation
#
#  newton iteration: 1, reldVnorm = 1.000000
#
#  damping iteration: 1, residual norm = 413051.066205
#
#  damping iteration: 2, residual norm = 0.864297
#
# exiting damping cycle
#
#
#  newton iteration: 2, reldVnorm = 0.007808
#
#  damping iteration: 1, residual norm = 0.864297
#
#  damping iteration: 2, residual norm = 330440.097717
#
# exiting damping cycle
#
#
# exiting newton cycle because reldVnorm= 0.000000
#
# updating electron qfl
# updating hole qfl
# checking for convergence
# max(|phin_(k+1)-phin_(k)| , |phip_(k+1)-phip_(k)| , |v_(k+1)- v_(k)|) = 14.21094405970354
# *****************************************************************
# ****    start of gummel iteration number: 996
# *****************************************************************
# solving non linear poisson equation
#
#  newton iteration: 1, reldVnorm = 1.000000
#
#  damping iteration: 1, residual norm = 54511.765671
#
#  damping iteration: 2, residual norm = 0.951291
#
# exiting damping cycle
#
#
#  newton iteration: 2, reldVnorm = 0.008152
#
#  damping iteration: 1, residual norm = 0.951291
#
#  damping iteration: 2, residual norm = 43609.380373
#
# exiting damping cycle
#
#
# exiting newton cycle because reldVnorm= 0.000000
#
# updating electron qfl
# updating hole qfl
# checking for convergence
# max(|phin_(k+1)-phin_(k)| , |phip_(k+1)-phip_(k)| , |v_(k+1)- v_(k)|) = 14.208929121574798
# *****************************************************************
# ****    start of gummel iteration number: 997
# *****************************************************************
# solving non linear poisson equation
#
#  newton iteration: 1, reldVnorm = 1.000000
#
#  damping iteration: 1, residual norm = 411677.327533
#
#  damping iteration: 2, residual norm = 0.858343
#
# exiting damping cycle
#
#
#  newton iteration: 2, reldVnorm = 0.007794
#
#  damping iteration: 1, residual norm = 0.858343
#
#  damping iteration: 2, residual norm = 329341.111139
#
# exiting damping cycle
#
#
# exiting newton cycle because reldVnorm= 0.000000
#
# updating electron qfl
# updating hole qfl
# checking for convergence
# max(|phin_(k+1)-phin_(k)| , |phip_(k+1)-phip_(k)| , |v_(k+1)- v_(k)|) = 14.20691380196536
# *****************************************************************
# ****    start of gummel iteration number: 998
# *****************************************************************
# solving non linear poisson equation
#
#  newton iteration: 1, reldVnorm = 1.000000
#
#  damping iteration: 1, residual norm = 54381.174769
#
#  damping iteration: 2, residual norm = 0.950259
#
# exiting damping cycle
#
#
#  newton iteration: 2, reldVnorm = 0.008137
#
#  damping iteration: 1, residual norm = 0.950259
#
#  damping iteration: 2, residual norm = 43504.907900
#
# exiting damping cycle
#
#
# exiting newton cycle because reldVnorm= 0.000000
#
# updating electron qfl
# updating hole qfl
# checking for convergence
# max(|phin_(k+1)-phin_(k)| , |phip_(k+1)-phip_(k)| , |v_(k+1)- v_(k)|) = 14.204902886517388
# *****************************************************************
# ****    start of gummel iteration number: 999
# *****************************************************************
# solving non linear poisson equation
#
#  newton iteration: 1, reldVnorm = 1.000000
#
#  damping iteration: 1, residual norm = 410310.571880
#
#  damping iteration: 2, residual norm = 0.852437
#
# exiting damping cycle
#
#
#  newton iteration: 2, reldVnorm = 0.007780
#
#  damping iteration: 1, residual norm = 0.852437
#
#  damping iteration: 2, residual norm = 328247.710944
#
# exiting damping cycle
#
#
# exiting newton cycle because reldVnorm= 0.000000
#
# updating electron qfl
# updating hole qfl
# checking for convergence
# max(|phin_(k+1)-phin_(k)| , |phip_(k+1)-phip_(k)| , |v_(k+1)- v_(k)|) = 14.202891589980194
#
#
# Initial guess computed by DD: # of Gummel iterations = 999
# Resulting odata: <class '__main__.Idata'>
# Number of iterations: 999
# Residuals: [36.98201734 26.98808842 26.23775015 25.47819741 25.04527991 24.60730019
#  24.30371447 23.99707417 23.76356231 23.52808199 23.33842811 23.14744098
#  22.98782837 22.82752732 22.68978807 22.5515836  22.4304614  22.30897583
#  22.20090172 22.09233149 21.99475025 21.89678062 21.80784146 21.71859402
#  21.63689466 21.55494617 21.47939731 21.40367376 21.33341858 21.26302808
#  21.19737513 21.13161042 21.06999454 21.00828281 20.95023647 20.89210618
#  20.8372403  20.78227424 20.73025403 20.6781562  20.62870308 20.57917416
#  20.53204517 20.48485619 20.43984346 20.39478068 20.35170263 20.30858135
#  20.26727865 20.22593773 20.18626984 20.14656766 20.1084101  20.07022146
#  20.03346415 19.99667181 19.96121483 19.92572626 19.89148078 19.85720875
#  19.82409514 19.79095836 19.7589045  19.72682991 19.69577028 19.6646918
#  19.63456672 19.6044243  19.57517926 19.54591817 19.51750324 19.48907339
#  19.46144274 19.43379817 19.40690965 19.38000811 19.35382285 19.32762538
#  19.30210748 19.27657813 19.25169438 19.22679985 19.20251947 19.17822894
#  19.15452335 19.13080817 19.10765078 19.08448433 19.06185038 19.03920784
#  19.0170742  18.99493241 18.97327746 18.95161477 18.93041826 18.90921439
#  18.88845731 18.86769323 18.84735774 18.82701558 18.80708489 18.78714784
#  18.76760614 18.74805837 18.72889077 18.70971737 18.69090979 18.67209667
#  18.65363585 18.63516972 18.61704309 18.59891136 18.58110704 18.56329783
#  18.54580456 18.52830659 18.51111368 18.49391626 18.47701358 18.46010655
#  18.44348446 18.42685819 18.41050753 18.39415283 18.37806488 18.36197303
#  18.34613947 18.33030215 18.31471505 18.29912433 18.28377615 18.26842446
#  18.25330798 18.23818809 18.22329641 18.20840143 18.19372796 18.1790513
#  18.16458973 18.15012507 18.13586938 18.12161068 18.10755507 18.09349655
#  18.07963549 18.0657716  18.05209978 18.0384252  18.02493752 18.01144715
#  17.99813871 17.98482765 17.97169374 17.95855729 17.9455934  17.93262703
#  17.9198288  17.90702816 17.89439142 17.88175233 17.86927305 17.85679147
#  17.84446577 17.83213782 17.81996197 17.80778392 17.79575431 17.78372255
#  17.77183571 17.75994678 17.74819936 17.73644989 17.72483865 17.71322541
#  17.70174724 17.6902671  17.67891897 17.66756892 17.65634792 17.64512504
#  17.63402835 17.62292982 17.61195472 17.6009778  17.59012166 17.57926372
#  17.56852397 17.55778247 17.54715664 17.5365291  17.5260148  17.51549882
#  17.50509374 17.494687   17.48438889 17.47408915 17.46389582 17.45370089
#  17.44361025 17.43351802 17.423528   17.41353643 17.40364504 17.39375214
#  17.38395746 17.37416128 17.36446144 17.35476012 17.3451533  17.33554502
#  17.32602944 17.31651242 17.30708637 17.2976589  17.28832071 17.27898112
#  17.26972916 17.26047582 17.25130851 17.24213985 17.23305566 17.22397014
#  17.21496757 17.20596369 17.19704129 17.1881176  17.17927395 17.17042902
#  17.16166275 17.15289521 17.14420497 17.13551348 17.12689796 17.1182812
#  17.10973913 17.10119583 17.09272596 17.08425488 17.07585601 17.06745593
#  17.05912687 17.05079662 17.04253622 17.03427464 17.02608177 17.01788774
#  17.00976131 17.00163374 16.99357268 16.98551048 16.97751375 16.96951589
#  16.96158246 16.95364792 16.94577681 16.93790459 16.93009481 16.92228394
#  16.91453455 16.90678408 16.89909415 16.89140316 16.88377178 16.87613935
#  16.86856565 16.86099089 16.85347399 16.84595605 16.83849511 16.83103314
#  16.82362732 16.81622049 16.80886899 16.80151649 16.79421852 16.78691955
#  16.77967434 16.77242813 16.76523491 16.75804071 16.75089875 16.74375581
#  16.73666437 16.72957196 16.72253034 16.71548776 16.70849526 16.70150181
#  16.69455775 16.68761275 16.68071646 16.67381924 16.66697008 16.66011998
#  16.65331729 16.64651368 16.63975685 16.6329991  16.6262875  16.61957499
#  16.61290803 16.60624016 16.59961724 16.59299343 16.58641398 16.57983364
#  16.57329708 16.56675964 16.56026543 16.55377034 16.54731793 16.54086464
#  16.53445349 16.52804147 16.52167105 16.51529977 16.50896958 16.50263853
#  16.49634805 16.49005672 16.48380546 16.47755336 16.47134083 16.46512747
#  16.4589532  16.4527781  16.44664161 16.4405043  16.43440515 16.42830517
#  16.42224289 16.41617979 16.41015394 16.40412728 16.39813743 16.39214677
#  16.38619248 16.3802374  16.37431826 16.36839832 16.36251392 16.35662872
#  16.35077865 16.34492778 16.33911164 16.33329471 16.3275121  16.32172871
#  16.31597926 16.31022903 16.30451235 16.2987949  16.29311062 16.28742558
#  16.28177334 16.27612033 16.27049977 16.26487845 16.25928921 16.25369921
#  16.24814095 16.24258194 16.23705431 16.23152593 16.2260286  16.22053053
#  16.21506316 16.20959506 16.20415734 16.19871888 16.19331048 16.18790135
#  16.18252196 16.17714183 16.17179114 16.16643972 16.16111741 16.15579439
#  16.15050018 16.14520524 16.13993883 16.1346717  16.12943279 16.12419317
#  16.11898148 16.11376908 16.10858432 16.10339887 16.09824077 16.09308198
#  16.08795028 16.08281787 16.07771229 16.072606   16.06752627 16.06244584
#  16.0573917  16.05233687 16.04730807 16.04227857 16.03727485 16.03227044
#  16.02729156 16.02231198 16.01735768 16.0124027  16.00747275 16.00254211
#  15.99763626 15.99272974 15.98784777 15.98296512 15.97810678 15.97324778
#  15.96841285 15.96357726 15.95876553 15.95395313 15.94916436 15.94437493
#  15.93960891 15.93484222 15.93009873 15.92535459 15.92063342 15.91591159
#  15.91121253 15.90651282 15.90183566 15.89715786 15.8925024  15.8878463
#  15.88321234 15.87857774 15.87396508 15.86935179 15.86476024 15.86016805
#  15.85559741 15.85102614 15.84647623 15.84192568 15.83739631 15.8328663
#  15.82835728 15.82384762 15.81935877 15.81486929 15.81040042 15.80593093
#  15.80148188 15.7970322  15.79260279 15.78817275 15.78376279 15.77935222
#  15.77496156 15.77057029 15.76619875 15.7618266  15.75747403 15.75312084
#  15.74878706 15.74445266 15.74013752 15.73582176 15.73152508 15.7272278
#  15.72294944 15.71867048 15.71441028 15.71014947 15.70590728 15.70166448
#  15.69744014 15.6932152  15.68900856 15.68480133 15.68061225 15.67642257
#  15.6722509  15.66807864 15.66392424 15.65976924 15.65563196 15.65149408
#  15.64737379 15.6432529  15.63914944 15.6350454  15.63095865 15.62687131
#  15.62280113 15.61873037 15.61467662 15.6106223  15.60658486 15.60254683
#  15.59852557 15.59450372 15.59049849 15.58649269 15.58250338 15.5785135
#  15.57453998 15.57056589 15.56660803 15.56264961 15.55870729 15.55476441
#  15.55083752 15.54691005 15.54299846 15.5390863  15.53518989 15.53129291
#  15.52741156 15.52352964 15.51966324 15.51579627 15.5119447  15.50809257
#  15.50425571 15.5004183  15.49659605 15.49277324 15.48896549 15.48515718
#  15.48136381 15.47756989 15.4737908  15.47001115 15.46624623 15.46248076
#  15.4587299  15.45497849 15.45124159 15.44750414 15.4437811  15.44005751
#  15.43634821 15.43263837 15.42894273 15.42524655 15.42156446 15.41788182
#  15.41421318 15.410544   15.40688871 15.40323289 15.39959086 15.39594829
#  15.39231942 15.38869001 15.38507421 15.38145787 15.37785503 15.37425166
#  15.37066171 15.36707122 15.36349405 15.35991635 15.35635188 15.35278688
#  15.34923501 15.34568262 15.34214327 15.33860339 15.33507647 15.33154902
#  15.32803444 15.32451933 15.32101701 15.31751416 15.314024   15.31053333
#  15.30705526 15.30357666 15.3001106  15.29664401 15.29318986 15.28973519
#  15.28629288 15.28285005 15.2794195  15.27598843 15.27256955 15.26915015
#  15.26574287 15.26233507 15.25893931 15.25554303 15.25215871 15.24877387
#  15.24540091 15.24202744 15.23866577 15.23530358 15.23195312 15.22860215
#  15.22526283 15.221923   15.21859474 15.21526597 15.2119487  15.20863092
#  15.20532457 15.20201771 15.1987222  15.19542619 15.19214146 15.18885622
#  15.18558219 15.18230766 15.17904427 15.17578037 15.17252754 15.16927421
#  15.16603188 15.16278905 15.15955715 15.15632475 15.15310321 15.14988117
#  15.14666993 15.14345819 15.14025718 15.13705567 15.13386482 15.13067348
#  15.12749273 15.12431149 15.12114078 15.11796958 15.11480884 15.11164762
#  15.10849679 15.10534548 15.1022045  15.09906303 15.09593184 15.09280017
#  15.0896787  15.08655675 15.08344496 15.08033267 15.07723048 15.07412781
#  15.07103516 15.06794203 15.06485888 15.06177524 15.05870151 15.0556273
#  15.05256295 15.04949812 15.04644308 15.04338756 15.04034178 15.03729552
#  15.03425895 15.03122189 15.02819446 15.02516655 15.02214822 15.0191294
#  15.0161201  15.01311033 15.01011001 15.00710922 15.00411783 15.00112597
#  14.99814346 14.99516048 14.99218679 14.98921263 14.98624772 14.98328233
#  14.98032614 14.97736947 14.97442195 14.97147395 14.96853505 14.96559567
#  14.96266533 14.95973452 14.9568127  14.95389041 14.95097706 14.94806324
#  14.9451583  14.9422529  14.93935634 14.93645931 14.93357107 14.93068236
#  14.9278024  14.92492197 14.92205023 14.91917802 14.91631447 14.91345044
#  14.91059502 14.90773913 14.90489179 14.90204399 14.8992047  14.89636494
#  14.89353364 14.89070188 14.88787853 14.88505473 14.88223928 14.87942338
#  14.8766158  14.87380777 14.87100801 14.86820779 14.8654158  14.86262336
#  14.8598391  14.85705439 14.85427783 14.85150081 14.84873189 14.84596252
#  14.8432012  14.84043943 14.83768568 14.83493148 14.83218525 14.82943856
#  14.82669981 14.82396061 14.8212293  14.81849754 14.81577363 14.81304927
#  14.81033271 14.80761571 14.80490648 14.80219679 14.79949484 14.79679244
#  14.79409772 14.79140256 14.78871505 14.78602709 14.78334674 14.78066595
#  14.77799273 14.77531906 14.77265292 14.76998634 14.76732725 14.76466772
#  14.76201565 14.75936313 14.75671804 14.75407249 14.75143433 14.74879573
#  14.74616448 14.74353278 14.74090839 14.73828355 14.73566599 14.73304799
#  14.73043723 14.72782602 14.72522202 14.72261757 14.72002029 14.71742257
#  14.71483198 14.71224095 14.70965701 14.70707264 14.70449533 14.70191757
#  14.69934685 14.69677568 14.69421151 14.6916469  14.68908925 14.68653116
#  14.68397999 14.68142839 14.67888368 14.67633853 14.67380024 14.67126152
#  14.66872961 14.66619728 14.66367173 14.66114576 14.65862653 14.65610688
#  14.65359396 14.6510806  14.64857393 14.64606684 14.6435664  14.64106554
#  14.6385713  14.63607664 14.63358857 14.63110008 14.62861815 14.6261358
#  14.62365998 14.62118373 14.61871399 14.61624382 14.61378013 14.61131601
#  14.60885833 14.60640023 14.60394854 14.60149643 14.59905071 14.59660456
#  14.59416476 14.59172454 14.58929065 14.58685633 14.58442831 14.58199987
#  14.5795777  14.5771551  14.57473874 14.57232196 14.5699114  14.56750041
#  14.5650956  14.56269037 14.5602913  14.55789181 14.55549844 14.55310466
#  14.55071697 14.54832886 14.54594683 14.54356437 14.54118796 14.53881114
#  14.53644033 14.5340691  14.53170386 14.52933821 14.52697852 14.52461841
#  14.52226424 14.51990965 14.51756098 14.51521188 14.51286868 14.51052506
#  14.50818729 14.50584911 14.50351677 14.50118401 14.49885705 14.49652969
#  14.4942081  14.49188611 14.48956986 14.48725321 14.48494229 14.48263095
#  14.48032532 14.47801928 14.47571892 14.47341815 14.47112304 14.46882752
#  14.46653762 14.46424732 14.46196263 14.45967753 14.45739801 14.45511808
#  14.45284371 14.45056894 14.4482997  14.44603005 14.44376591 14.44150137
#  14.43924232 14.43698286 14.43472886 14.43247446 14.4302255  14.42797614
#  14.42573219 14.42348784 14.42124888 14.41900953 14.41677554 14.41454115
#  14.41231211 14.41008267 14.40785856 14.40563404 14.40341483 14.40119522
#  14.39898089 14.39676616 14.39455669 14.39234682 14.39014219 14.38793716
#  14.38573734 14.38353713 14.38134211 14.3791467  14.37695646 14.37476582
#  14.37258033 14.37039445 14.3682137  14.36603255 14.36385651 14.36168007
#  14.35950873 14.35733698 14.35517031 14.35300324 14.35084122 14.34867881
#  14.34652142 14.34436364 14.34221086 14.34005769 14.33790951 14.33576094
#  14.33361733 14.33147333 14.32933427 14.32719483 14.32506031 14.3229254
#  14.32079539 14.318665   14.31653949 14.31441359 14.31229256 14.31017114
#  14.30805457 14.3059376  14.30382547 14.30171295 14.29960524 14.29749714
#  14.29539383 14.29329013 14.29119121 14.28909189 14.28699733 14.28490238
#  14.28281217 14.28072157 14.27863569 14.27654942 14.27446785 14.2723859
#  14.27030862 14.26823096 14.26615796 14.26408457 14.26201583 14.2599467
#  14.2578822  14.25581731 14.25375703 14.25169637 14.2496403  14.24758384
#  14.24553196 14.24347969 14.24143198 14.23938389 14.23734033 14.23529639
#  14.23325698 14.23121717 14.22918188 14.2271462  14.22511501 14.22308343
#  14.22105633 14.21902884 14.21700581 14.2149824  14.21296342 14.21094406
#  14.20892912 14.2069138  14.20490289 14.20289159]
